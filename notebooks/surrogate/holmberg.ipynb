# %% [markdown]
# # Getting a prior for the declination time from Holmberg (1988)
#
# We use the measurements from Holmberg (1988) for the **normal voice** loudness modality.
#
# This could be extended with the soft and loud voice modalities. For the female soft voice, see the erratum Holmberg (1989a). With this we could also get more precise bounds. But this is unlikely to influence the prior for $\theta$ (such as $r$) downstream, so we skip this refinement. The tables were extracted with <https://www.extracttable.com/>.

# %%
from surrogate import holmberg
import jax
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# %%
df = pd.concat([holmberg.read("men"), holmberg.read("women")])
df
# Out:
#                                   parameter        x      sd        range  \
# 0                                  SPL (dB)   79.500   3.300    73.4-85.9
# 1                                   F0 (Hz)  116.000  12.000       93-135
# 2                         pressure (cm H2O)    6.300   1.400      4.2-9.6
# 3                        average flow (l/s)    0.190   0.070      0.1-0.3
# 4           glottal resistance (cm H2O/l/s)   37.700  16.700    12.3-77.2
# 5                                  SPL (dB)   79.500   3.400    73.3-87.0
# 6                                period (s)    0.009   0.001  0.007-0.011
# 7   maximum airflow declination rate (l/s²)  279.600  90.400  139.5-470.1
# 8                           peak flow (l/s)    0.380   0.090    0.21-0.54
# 9                             ac flow (l/s)    0.260   0.070    0.16-0.42
# 10                       minimum flow (l/s)    0.120   0.070    0.02-0.29
# 11                            open quotient    0.600   0.070    0.46-0.77
# 12                           speed quotient    1.820   0.280    1.32-2.58
# 13                         closing quotient    0.220   0.040    0.14-0.27
# 14                                    ac/dc    0.600   0.230    0.23-1.12
# 15                        pressure (cm H2O)    6.400   1.400      4.3-9.7
# 16                       average flow (l/s)    0.200   0.700    0.09-0.36
# 17          glottal resistance (cm H2O/l/s)   37.300  17.500    13.8-85.3
# 0                                  SPL (dB)   76.400   4.000    66.9-81.3
# 1                                   F0 (Hz)  205.000  24.000      162-237
# 2                         pressure (cm H2O)    5.800   0.900      4.4-7.6
# 3                        average flow (l/s)    0.140   0.030    0.09-0.21
# 4           glottal resistance (cm H2O/l/s)   42.200   8.100    27.9-92.5
# 5                                  SPL (dB)   76.400   4.000    66.9-81.4
# 6                                period (s)    0.005   0.001  0.004-0.006
# 7   maximum airflow declination rate (l/s²)  164.000  57.500   91.0-279.0
# 8                           peak flow (l/s)    0.220   0.060    0.12-0.37
# 9                             ac flow (l/s)    0.140   0.050    0.09-0.25
# 10                       minimum flow (l/s)    0.090   0.040    0.01-0.16
# 11                            open quotient    0.760   0.100    0.56-0.95
# 12                           speed quotient    1.650   0.300    1.19-2.33
# 13                         closing quotient    0.290   0.040    0.21-0.37
# 14                                    ac/dc    0.380   0.130    0.25-0.78
# 15                        pressure (cm H2O)    5.800   1.100      3.6-8.1
# 16                       average flow (l/s)    0.140   0.030    0.09-0.22
# 17          glottal resistance (cm H2O/l/s)   42.700   8.700    29.6-61.9
#
#       sex    lower    upper
# 0     men   73.400   85.900
# 1     men   93.000  135.000
# 2     men    4.200    9.600
# 3     men    0.100    0.300
# 4     men   12.300   77.200
# 5     men   73.300   87.000
# 6     men    0.007    0.011
# 7     men  139.500  470.100
# 8     men    0.210    0.540
# 9     men    0.160    0.420
# 10    men    0.020    0.290
# 11    men    0.460    0.770
# 12    men    1.320    2.580
# 13    men    0.140    0.270
# 14    men    0.230    1.120
# 15    men    4.300    9.700
# 16    men    0.090    0.360
# 17    men   13.800   85.300
# 0   women   66.900   81.300
# 1   women  162.000  237.000
# 2   women    4.400    7.600
# 3   women    0.090    0.210
# 4   women   27.900   92.500
# 5   women   66.900   81.400
# 6   women    0.004    0.006
# 7   women   91.000  279.000
# 8   women    0.120    0.370
# 9   women    0.090    0.250
# 10  women    0.010    0.160
# 11  women    0.560    0.950
# 12  women    1.190    2.330
# 13  women    0.210    0.370
# 14  women    0.250    0.780
# 15  women    3.600    8.100
# 16  women    0.090    0.220
# 17  women   29.600   61.900

# %%
from surrogate.holmberg import process_sexes

pdf = pd.concat(
    [
        process_sexes(df, "F0 (Hz)"),
        process_sexes(df, "open quotient"),
        process_sexes(df, "speed quotient"),
        process_sexes(df, "closing quotient"),
        process_sexes(df, "ac flow (l/s)"),
        process_sexes(df, "maximum airflow declination rate (l/s²)"),
    ]
)

pdf
# Out:
#                                  parameter        x          sd  lower   upper
# 0                                  F0 (Hz)  160.500   26.832816  93.00  237.00
# 0                            open quotient    0.680    0.122066   0.46    0.95
# 0                           speed quotient    1.735    0.410366   1.19    2.58
# 0                         closing quotient    0.255    0.056569   0.14    0.37
# 0                            ac flow (l/s)    0.200    0.086023   0.09    0.42
# 0  maximum airflow declination rate (l/s²)  221.800  107.137342  91.00  470.10

# %% [markdown]
# We see a very good fit of our prior to the $T_d$ data simulated from Holmberg.

# %%
U0 = holmberg.truncnorm(df, "ac flow (l/s)")
Ee = holmberg.truncnorm(df, "maximum airflow declination rate (l/s²)")

NUMSAMPLES = int(1e5)

Td = U0.rvs(NUMSAMPLES) / Ee.rvs(NUMSAMPLES) * 1000  # msec

display(pd.DataFrame(Td).describe())

prior = holmberg.declination_time_prior()
samples = prior.sample(NUMSAMPLES, seed=jax.random.PRNGKey(50))

fig = go.Figure()
fig.add_trace(
    go.Histogram(
        x=Td,
        nbinsx=50,
        histnorm="probability density",
        opacity=0.5,
        name="Holmberg",
    )
)
fig.add_trace(
    go.Histogram(
        x=np.array(samples),
        nbinsx=50,
        histnorm="probability density",
        opacity=0.5,
        name="prior",
    )
)
fig.update_layout(
    barmode="overlay",
    title="Prior for the declination time",
)
fig.update_xaxes(title=r"$\mathrm{declination\ time}\ T_d\ \mathrm{[msec]}$")
fig.show()
# Out:
#                    0
# count  100000.000000
# mean        1.024863
# std         0.549214
# min         0.199950
# 25%         0.635322
# 50%         0.894596
# 75%         1.273055
# max         4.567901
# [Memory]374.8s, 6.2min  : Loading run_nested...

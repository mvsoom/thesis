# %%
from utils.plots import plt

# %%
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Test Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([0, 1, 2, 3], [0, 1, 4, 9], label="quadratic $ax^2 + b$")
ax.set_title("Test figure")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend()

# %%
from utils.plots import retain, reopen

paths = retain(fig)
# Out:
# <ul><li><b>pdf</b>: <a href="../../figures/20250904125927178.pdf">../../figures/20250904125927178.pdf</a></li><li><b>png</b>: <a href="../../figures/20250904125927178.png">../../figures/20250904125927178.png</a></li><li><b>svg</b>: <a href="../../figures/20250904125927178.svg">../../figures/20250904125927178.svg</a></li><li><b>pickle</b>: <a href="../../figures/20250904125927178.pkl">../../figures/20250904125927178.pkl</a></li></ul>

# %%
fig2 = reopen(paths["pickle"])
ax2 = fig2.axes[0]
ax2.set_title("Tweaked figure -- new title!")
# make figure smaller too
fig2.set_size_inches(2, 1)
fig2

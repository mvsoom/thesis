# %%
from utils.plots import plt

# %%
fig, ax = plt.subplots()
ax.plot([0, 1, 2, 3], [0, 1, 4, 9], label="quadratic $ax^2 + b \int_x e^x$")
ax.set_title("Test figure")
ax.set_xlabel("$x$")
ax.set_ylabel("$y$")
ax.legend()
fig

# %%
from utils.plots import retain, reopen

paths = retain(fig)
# Out:
# <ul><li><b>pdf</b>: <a href="../../figures/pdf/20250904150928444.pdf">../../figures/pdf/20250904150928444.pdf</a></li><li><b>png</b>: <a href="../../figures/png/20250904150928444.png">../../figures/png/20250904150928444.png</a></li><li><b>svg</b>: <a href="../../figures/svg/20250904150928444.svg">../../figures/svg/20250904150928444.svg</a></li><li><b>pickle</b>: <a href="../../figures/pkl/20250904150928444.pkl">../../figures/pkl/20250904150928444.pkl</a></li></ul>

# %%
paths = retain(fig, col="2col")
# Out:
# <ul><li><b>pdf</b>: <a href="../../figures/pdf/20250904150930975.pdf">../../figures/pdf/20250904150930975.pdf</a></li><li><b>png</b>: <a href="../../figures/png/20250904150930975.png">../../figures/png/20250904150930975.png</a></li><li><b>svg</b>: <a href="../../figures/svg/20250904150930975.svg">../../figures/svg/20250904150930975.svg</a></li><li><b>pickle</b>: <a href="../../figures/pkl/20250904150930975.pkl">../../figures/pkl/20250904150930975.pkl</a></li></ul>

# %%
fig2 = reopen(paths["pickle"])
ax2 = fig2.axes[0]
ax2.set_title("Tweaked figure -- new title!")
# make figure smaller too
fig2.set_size_inches(2, 1)
fig2
